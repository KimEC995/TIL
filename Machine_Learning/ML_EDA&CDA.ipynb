# %% [markdown]
# # 데이터 분석의종류

# %% [markdown]
# ---
#
# ## 목차
#
# 1.

# %% [markdown]
# ### 1. CDA(Confirmatory Data Analysis)
#
# > 확증적 데이터 분석

# %% [markdown]
# CDA는 가설을 설정한 후 **수집한 데이터로 가설을 평가하고 추정하는 전통적인 분석** 이다. \
# 관측 된 형태나 효과의 재현성 평가, 유의성 검정, 신뢰구간 추정 등 통계적 추론을 하는 분석 방법으로 설문조사나 논문의 내용을 입증하는데 사용한다.

# %% [markdown]
# - 확증적 데이터 분석(CDA) 의 단계
# ![image.png](attachment:image.png)
